# %%
#%pip install spacy
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 3
#       1 #%pip install spacy
#       2 import spacy
# ----> 3 nlp = spacy.load("en_core_web_sm")
#
# File c:\Users\julia\torch-env\Lib\site-packages\spacy\__init__.py:74, in load(name, vocab, disable, enable, exclude, config)
#      50 def load(
#      51     name: Union[str, Path],
#      52     *,
#    (...)     57     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      58 ) -> Language:
#      59     """Load a spaCy model from an installed package or a local path.
#      60
#      61     name (str): Package name or model path.
#    (...)     72     RETURNS (Language): The loaded nlp object.
#      73     """
# ---> 74     return util.load_model(
#      75         name,
#      76         vocab=vocab,
#      77         disable=disable,
#      78         enable=enable,
# ...

# %%
pip install beautifulsoup4 requests pandas pymupdf lxml
# Out:
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/19.2 MB 11.2 MB/s eta 0:00:02
#    -------- ------------------------------- 4.2/19.2 MB 15.7 MB/s eta 0:00:01
#    ------------------- -------------------- 9.2/19.2 MB 17.3 MB/s eta 0:00:01
#    --------------------------- ------------ 13.1/19.2 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 16.5/19.2 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 17.5 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 15.8 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------------------------ --- 3.7/4.0 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 15.1 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pymupdf]
#    ---------------------------------------- 0/2 [pymupdf]
# ...
